# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # batsman class

# %%
class batsman:
    data=pd.read_csv('Batsman_Data.csv',sep=",")
    data=pd.DataFrame(data)

# %% [markdown]
# # Bolwer class

# %%
class bowler:
    data=pd.read_csv('Bowler_data.csv',sep=",")
    data=pd.DataFrame(data)

# %% [raw]
# #

# %%
bat=batsmans()
bat.data
# Out:
#        Unnamed: 0 Bat1  Runs  BF    SR  4s  6s    Opposition     Ground  \
# 0               1    0     0   0   0.0   0   0       v India     Nagpur
# 1               2    0     0   0   0.0   0   0       v India    Kolkata
# 2               3    0     0   0   0.0   0   0       v India      Delhi
# 3               4    0     0   0   0.0   0   0  v Bangladesh      Dhaka
# 4               5    0     0   0   0.0   0   0       v India      Dhaka
# ...           ...  ...   ...  ..   ...  ..  ..           ...        ...
# 11144       11145   46    46  61  75.4   6   1     v Ireland   Dehradun
# 11145       11146    3     3   6  50.0   0   0     v Ireland   Dehradun
# 11146       11147    1     1   8  12.5   0   0     v Ireland   Dehradun
# 11147       11148    0     0   0   0.0   0   0    v Scotland  Edinburgh
# 11148       11149   T0     0   0   0.0   0   0     v Ireland    Belfast
#
#       Start Date    Match_ID         Batsman  Player_ID
# 0      18-Dec-09  ODI # 2933   Oshane Thomas      49619
# 1      24-Dec-09  ODI # 2935   Oshane Thomas      49619
# 2      27-Dec-09  ODI # 2936   Oshane Thomas      49619
# 3       4-Jan-10  ODI # 2937   Oshane Thomas      49619
# 4       5-Jan-10  ODI # 2938   Oshane Thomas      49619
# ...          ...         ...             ...        ...
# 11144  28-Feb-19  ODI # 4100  Gulbadin Naib      352048
# 11145   2-Mar-19  ODI # 4101  Gulbadin Naib      352048
# 11146   8-Mar-19  ODI # 4108  Gulbadin Naib      352048
# 11147  10-May-19  ODI # 4131  Gulbadin Naib      352048
# 11148  19-May-19  ODI # 4139  Gulbadin Naib      352048
#
# [11149 rows x 13 columns]
