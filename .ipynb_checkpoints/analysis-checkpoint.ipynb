# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

class batsman:
    df=pd.read_csv('Batsman_Data.csv',sep=",")
    df=pd.DataFrame(df)
    

Bowler_data=pd.read_csv('Bowler_data.csv',sep=",")
Bowler_data=pd.DataFrame(Bowler_data)
Ground_Averages=pd.read_csv('Ground_Averages.csv',sep=",")
Ground_Averages=pd.DataFrame(Ground_Averages)
ODI_Match_Results=pd.read_csv('ODI_Match_Results.csv',sep=",")
ODI_Match_Results=pd.DataFrame(ODI_Match_Results)
ODI_Match_Totals=pd.read_csv('ODI_Match_Totals.csv',sep=",")
ODI_Match_Totals=pd.DataFrame(ODI_Match_Totals)
WC_players=pd.read_csv('WC_players.csv',sep=",")
WC_players=pd.DataFrame(WC_players)

# %% [markdown]
# # Total Runs and Wickets

# %%
# Total Runs and Wickets

total_runs=batsman(sum(batsman.df['Runs']))
total_Wkts=sum(Bowler_data['Wkts'])

# Total overs and median overs

total_Overs=sum(Bowler_data['Overs'])
total_Mdns=sum(Bowler_data['Mdns'])

# Total no of sixs and fours 

batsman.total_6s=sum(batsman.df['6s'])
batsman.total_4s=sum(batsman.df['4s'])

# %%
print("Total runs score by all batsmans :: ",total_runs," Runs")
print("Total wickets by all blowers :: ",total_Wkts," Wickets")
print("Total no Overs :: ",round(total_Wkts,5)," Overs")
print("Total no medain Overs :: ",round(total_Mdns,5),"  median Overs")
print("Total no of sixs :: ",batsman.total_6s," sixs..")
print("Total no of fours :: ",batsman.total_4s," fours..")
# Out:
# Total runs score by all batsmans ::  256030  Runs
# Total wickets by all blowers ::  6762  Wickets
# Total no Overs ::  6762  Overs
# Total no medain Overs ::  1799   median Overs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       3 print("Total no Overs :: ",round(total_Wkts,5)," Overs")
#       4 print("Total no medain Overs :: ",round(total_Mdns,5),"  median Overs")
# ----> 5 print("Total no of sixs :: ",batsman.total_6s," sixs..")
#       6 print("Total no of fours :: ",batsman.total_4s," fours..")
#
# AttributeError: type object 'batsman' has no attribute 'total_6s'

# %% [markdown]
# # no of players from each country

# %%
sns.countplot(y=WC_players.Country)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %% [markdown]
# # matchs played in each team
# ## From 3- jan -2013 TO 19- May-2019

# %%
sns.countplot(y=ODI_Match_Totals.Country)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %% [markdown]
# # matches played since jan-2013 to may-2019

# %%
sns.countplot(y=(ODI_Match_Totals.Country))
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %%
most_matches={1:"Sri Lanka",2:"India",3:"England"}
print("most matches are played by :: ",most_matches[1])
print("2nd :: ",most_matches[2])
print("3rd :: ",most_matches[3])
# Out:
# most matches are played by ::  Sri Lanka
# 2nd ::  India
# 3rd ::  England

# %% [markdown]
# # highest scoring ground

# %%
sns.catplot(x="Runs",y="Ground",data=batsman_data.nlargest(30,'Runs'),kind="bar")
plt.title("highest scoring ground")
# Out:
# Text(0.5, 1.0, 'highest scoring ground')

# %%
print("from graph of highest scoring ground we have  ranking as :: ")
high_scoring_ground={1:"Kolkata",2:"wellington",3:"Canberra"}
print("1st ::",high_scoring_ground[1])
print("2nd ::",high_scoring_ground[2])
print("3rd ::",high_scoring_ground[3])
# Out:
# from graph of highest scoring ground we have  ranking as ::
# 1st :: Kolkata
# 2nd :: wellington
# 3rd :: Canberra

# %% [markdown]
# # heighest wicket taking ground

# %%
sns.catplot(x="Wkts",y="Ground",data=Bowler_data.nlargest(30,'Wkts'),kind="bar")
plt.title("highest wickets taking ground")
# Out:
# Text(0.5, 1.0, 'highest wickets taking ground')

# %%
print("from graph of highest wicket taking ground we have  ranking as :: ")
high_wicket_tacking_ground={1:"Basseterre",2:"christichurch",3:"wellington"}
print("1st ::",high_wicket_tacking_ground[1])
print("2nd ::",high_wicket_tacking_ground[2])
print("3rd ::",high_wicket_tacking_ground[3])
# Out:
# from graph of highest wicket taking ground we have  ranking as ::
# 1st :: Basseterre
# 2nd :: christichurch
# 3rd :: wellington

# %% [markdown]
# # players to play most matches

# %%
new = batsman_data['Batsman'].value_counts()[:100]
h_match_played=pd.DataFrame(new)
h_match_played
# Out:
#                Batsman
# MS Dhoni           341
# Chris Gayle        289
# Shoaib Malik       284
# Virat Kohli        227
# Eoin Morgan        222
# ...                ...
# Fakhar Zaman        36
# Evin Lewis          35
# Haris Sohail        34
# Shadab Khan         34
# Nuwan Pradeep       34
#
# [100 rows x 1 columns]

# %% [markdown]
# # Batsmans induvidual data

# %%
bd_opposition = batsman_data.query('Opposition =="v England" and Batsman=="MS Dhoni "')
bd_opposition
#sum(bd_opposition.Runs)
# Out:
#       Unnamed: 0 Bat1  Runs   BF      SR  4s  6s Opposition  \
# 6013        6014   20    20   28   71.42   2   0  v England
# 6014        6015   38    38   55   69.09   2   0  v England
# 6015        6016  13*    13    6  216.66   1   1  v England
# 6016        6017  10*    10   13   76.92   1   0  v England
# 6017        6018   96    96  106   90.56  10   3  v England
# 6030        6031    7     7   22   31.81   0   0  v England
# 6055        6056   19    19   60   31.66   1   0  v England
# 6056        6057   21    21   18  116.66   3   0  v England
# 6057        6058   13    13   20   65.00   0   0  v England
# 6058        6059   13    13   18   72.22   1   0  v England
# 6059        6060   24    24   17  141.17   3   0  v England
# 6060        6061   35    35   37   94.59   3   0  v England
# 6061        6062   50    50   72   69.44   4   1  v England
# 6098        6099   39    39   32  121.87   3   1  v England
# 6099        6100   15    15   26   57.69   1   0  v England
# 6100        6101  29*    29   51   56.86   4   0  v England
# 6101        6102    9     9    5  180.00   0   1  v England
# 6102        6103   50    50   61   81.96   5   0  v England
# 6156        6157   31    31   25  124.00   3   1  v England
# 6164        6165   33    33   36   91.66   2   0  v England
# 6165        6166    6     6    5  120.00   1   0  v England
# 6166        6167   69    69  103   66.99   5   0  v England
# 6167        6168  78*    78   71  109.85   6   3  v England
# 6168        6169  50*    50   26  192.30   5   2  v England
# 6169        6170  87*    87   70  124.28  10   1  v England
# 6170        6171    0     0    0    0.00   0   0  v England
# 6171        6172  35*    35   31  112.90   3   0  v England
# 6172        6173  15*    15   18   83.33   1   1  v England
# 6173        6174  75*    75   69  108.69   3   4  v England
# 6192        6193   32    32   25  128.00   0   4  v England
# 6193        6194   72    72   66  109.09   7   2  v England
# 6194        6195  10*    10   12   83.33   2   0  v England
# 6195        6196   19    19   21   90.47   2   0  v England
# 6196        6197   15    15   23   65.21   2   0  v England
# 6201        6202    0     0    4    0.00   0   0  v England
# 6221        6222   52    52   51  101.96   6   0  v England
# 6222        6223    0     0    0    0.00   0   0  v England
# 6223        6224    0     0    0    0.00   0   0  v England
# 6224        6225   29    29   42   69.04   1   1  v England
# 6229        6230   34    34   61   55.73   1   0  v England
# 6231        6232   17    17   32   53.12   3   0  v England
# 6261        6262    6     6    6  100.00   1   0  v England
# 6262        6263  134   134  122  109.83  10   6  v England
# 6263        6264   25    25   36   69.44   1   1  v England
# 6296        6297    0     0    0    0.00   0   0  v England
# 6297        6298   37    37   59   62.71   2   0  v England
# 6298        6299   42    42   66   63.63   4   0  v England
#
#                   Ground Start Date    Match_ID    Batsman  Player_ID
